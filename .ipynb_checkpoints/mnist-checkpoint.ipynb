# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/wiatrak2/BScThesis/blob/master/mnist.ipynb)

# %%
# !pip3 install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (5.3.0)

# %%
# !git clone https://github.com/wiatrak2/BScThesis
# Out:
# fatal: destination path 'BScThesis' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('BScThesis/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import torchvision
import torchvision.transforms as transforms

# %%
import matplotlib.pyplot as plt
import pickle
import sympy
from collections import defaultdict, namedtuple
import copy

# %%
from mnist_m import Mnist_M
from datasets_merge import Merge_Datasets
import models
import trainer
import domain_trainer
from test_model import test_model
import plots
import test

# %%
def convertMnist(img):
  img = img.squeeze().numpy()
  return torch.from_numpy(np.tile(img, (3,1,1)))

# %%
batch_size=64
num_workers=1

# %%
transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,)),
                           transforms.Lambda(convertMnist)
                       ])

train_set = torchvision.datasets.MNIST(root='./data', train=True, download=True,
                                     transform=transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size,
                                         shuffle=True, num_workers=num_workers)

test_set = torchvision.datasets.MNIST(root='./data', train=False, download=True,
                                     transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size,
                                         shuffle=False, num_workers=num_workers)

# %%
def printMnist3D(image):
  image = image.numpy()
  image = image * 0.3081 + 0.1307
  plt.imshow(image.transpose(1,2,0), cmap='gray')

# %%
trainiter = iter(train_loader)
images, labels = trainiter.next()

sample = images[0]
printMnist3D(sample)
print(labels[0].item())
# Out:
# 4

# %%
log_interval = 100

# %%
use_cuda = True
use_cuda = use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
lr = 0.01
momentum=0.9

# %%
mnist_m_transform = transforms.Compose([
                           transforms.Normalize(3*[0.1307], 3*[0.3081]),
                       ])
mnist_m_train = Mnist_M('drive/My Drive/BScThesis/keras_mnistm.pkl',
                        transform=mnist_m_transform)
mnist_m_test = Mnist_M('drive/My Drive/BScThesis/keras_mnistm.pkl',train=False,
                     transform=mnist_m_transform)
mnist_m_train_loader = torch.utils.data.DataLoader(mnist_m_train, 
                                                   batch_size=batch_size,
                                         shuffle=True, num_workers=num_workers)
mnist_m_test_loader = torch.utils.data.DataLoader(mnist_m_test,
                                                  batch_size=batch_size,
                                         shuffle=False, num_workers=num_workers)

# %%
trainiter = iter(mnist_m_train_loader)
images, labels = trainiter.next()
printMnist3D(images[0])
print(labels[0])
# Out:
# tensor(6)

# %%
mnist_ext_train = Merge_Datasets([train_set, mnist_m_train])
mnist_ext_test = Merge_Datasets([test_set, mnist_m_test])
mnist_ext_train_loader = torch.utils.data.DataLoader(mnist_ext_train, 
                                                   batch_size=batch_size,
                                         shuffle=True, num_workers=num_workers)
mnist_ext_test_loader = torch.utils.data.DataLoader(mnist_ext_test, 
                                                   batch_size=batch_size,
                                         shuffle=True, num_workers=num_workers)

# %%
criterion = F.nll_loss
criterion_domain = F.nll_loss

# %%
Models = namedtuple('Models', ['model_f', 'model_c', 'model_d'])
Optims = namedtuple('Optims', ['optim_f', 'optim_c', 'optim_d'])
Criterions = namedtuple('Criterions', ['criterion', 'criterion_domain'])
Loaders = namedtuple('Loaders', ['train_loader', 'train_loader_domain',
                                'source_test_loader', 'target_test_loader',
                                'merged_test_loader'])

# %%
epochs=10

# %%
model_f = models.MnistFeatureExtractor().to(device)
model_c = models.MnistClassPredictor().to(device)
model_d = models.MnistDomain().to(device)
optim_f = optim.SGD(model_f.parameters(), lr=lr, momentum=momentum)
optim_c = optim.SGD(model_c.parameters(), lr=lr, momentum=momentum)
optim_d = optim.SGD(model_d.parameters(), lr=lr, momentum=momentum)

train_models = Models(model_f, model_c, model_d)
optims = Optims(optim_f, optim_c, optim_d)
criterions = Criterions(criterion, criterion_domain)
loaders = Loaders(train_loader, mnist_m_train_loader,
                 test_loader, mnist_m_test_loader, mnist_ext_test_loader)

# %%
model_trainer = trainer.Trainer(train_models, optims, criterions, device)

# %%
test_history = defaultdict(lambda:[])
train_history = defaultdict(lambda:[])
model_trainer.train(epochs, loaders, train_history=train_history, test_history=test_history)
# Out:
# Train Epoch: 					1 [0/60000 (0%)]	Loss: 2.284795, p: 0.00000 lambd: 0.00000
# Train Epoch: 					1 [6400/60000 (11%)]	Loss: 0.923963, p: 0.01067 lambd: 0.05328
# Train Epoch: 					1 [12800/60000 (21%)]	Loss: 0.465705, p: 0.02133 lambd: 0.10626
# Train Epoch: 					1 [19200/60000 (32%)]	Loss: 0.625056, p: 0.03200 lambd: 0.15865
# Train Epoch: 					1 [25600/60000 (43%)]	Loss: 0.476686, p: 0.04267 lambd: 0.21015
# Train Epoch: 					1 [32000/60000 (53%)]	Loss: 0.504729, p: 0.05333 lambd: 0.26052
# Train Epoch: 					1 [38400/60000 (64%)]	Loss: 0.591555, p: 0.06400 lambd: 0.30951
# Train Epoch: 					1 [44800/60000 (75%)]	Loss: 0.239504, p: 0.07467 lambd: 0.35690
# Train Epoch: 					1 [51200/60000 (85%)]	Loss: 0.373695, p: 0.08533 lambd: 0.40253
# Train Epoch: 					1 [57600/60000 (96%)]	Loss: 0.202107, p: 0.09600 lambd: 0.44624
#
# Target Domain Test set: Average loss: 1.0866, Accuracy: 6887/10000 (69%)
#
# Source Domain Test set: Average loss: 0.0964, Accuracy: 9698/10000 (97%)
#
# Domains predictor:  Accuracy: 13335/20000 (67%)
#
# Train Epoch: 					2 [0/60000 (0%)]	Loss: 0.154089, p: 0.10000 lambd: 0.46212
# Train Epoch: 					2 [6400/60000 (11%)]	Loss: 0.180219, p: 0.11067 lambd: 0.50301
# Train Epoch: 					2 [12800/60000 (21%)]	Loss: 0.307765, p: 0.12133 lambd: 0.54178
# Train Epoch: 					2 [19200/60000 (32%)]	Loss: 0.250268, p: 0.13200 lambd: 0.57836
# Train Epoch: 					2 [25600/60000 (43%)]	Loss: 0.244819, p: 0.14267 lambd: 0.61276
# Train Epoch: 					2 [32000/60000 (53%)]	Loss: 0.232061, p: 0.15333 lambd: 0.64499
# Train Epoch: 					2 [38400/60000 (64%)]	Loss: 0.281228, p: 0.16400 lambd: 0.67507
# Train Epoch: 					2 [44800/60000 (75%)]	Loss: 0.187786, p: 0.17467 lambd: 0.70306
# Train Epoch: 					2 [51200/60000 (85%)]	Loss: 0.064916, p: 0.18533 lambd: 0.72904
# Train Epoch: 					2 [57600/60000 (96%)]	Loss: 0.544400, p: 0.19600 lambd: 0.75307
#
# Train Epoch: 					10 [6400/60000 (11%)]	Loss: 0.102221, p: 0.91067 lambd: 0.99978
# Train Epoch: 					10 [12800/60000 (21%)]	Loss: 0.116413, p: 0.92133 lambd: 0.99980
# Train Epoch: 					10 [19200/60000 (32%)]	Loss: 0.080906, p: 0.93200 lambd: 0.99982
# Train Epoch: 					10 [25600/60000 (43%)]	Loss: 0.168917, p: 0.94267 lambd: 0.99984
# Train Epoch: 					10 [32000/60000 (53%)]	Loss: 0.192000, p: 0.95333 lambd: 0.99986
# Train Epoch: 					10 [38400/60000 (64%)]	Loss: 0.132564, p: 0.96400 lambd: 0.99987
# Train Epoch: 					10 [44800/60000 (75%)]	Loss: 0.133416, p: 0.97467 lambd: 0.99988
# Train Epoch: 					10 [51200/60000 (85%)]	Loss: 0.318473, p: 0.98533 lambd: 0.99989
# Train Epoch: 					10 [57600/60000 (96%)]	Loss: 0.176135, p: 0.99600 lambd: 0.99991
#
# Target Domain Test set: Average loss: 0.9685, Accuracy: 7422/10000 (74%)
#
# Source Domain Test set: Average loss: 0.0594, Accuracy: 9817/10000 (98%)
#
# Domains predictor:  Accuracy: 13884/20000 (69%)

# %%
mnist_pred = nn.Sequential(model_f, model_c)
test_model(mnist_pred, device, criterions, mnist_m_test_loader)
# Out:
# Test set: Average loss: 0.9685, Accuracy: 7422/10000 (74%)

# %%
mnist_pred = nn.Sequential(model_f, model_c)
test_model(mnist_pred, device, criterions, test_loader)
# Out:
# Test set: Average loss: 0.0594, Accuracy: 9817/10000 (98%)

# %%
plots.plotTraining(train_history)

# %%
plots.plotTest(test_history)

# %%
domain_pred = models.DomainPredictor().to(device)
domain_optim = optim.SGD(domain_pred.parameters(), lr=lr, momentum=momentum)

# %%
models_dom = Models(model_f, None, domain_pred)
optims_dom = Optims(None, None, optim_d=domain_optim)
domain_trainer = domain_trainer.DomainTrainer(models_dom, optims_dom, criterions, device)

# %%
domain_train_history = defaultdict(lambda:[])
domain_trainer.train(4, loaders, train_models, train_history=domain_train_history)
# Out:
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.331612
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.265611
#
# Domains predictor:  Accuracy: 17878/20000 (89%)
#
# Train Epoch: 2 [0/20000 (0%)]	Loss: 0.352836
# Train Epoch: 2 [12800/20000 (64%)]	Loss: 0.332810
#
# Domains predictor:  Accuracy: 18053/20000 (90%)
#
# Train Epoch: 3 [0/20000 (0%)]	Loss: 0.278422
# Train Epoch: 3 [12800/20000 (64%)]	Loss: 0.386214
#
# Domains predictor:  Accuracy: 18291/20000 (91%)
#
# Train Epoch: 4 [0/20000 (0%)]	Loss: 0.311053
# Train Epoch: 4 [12800/20000 (64%)]	Loss: 0.177366
#
# Domains predictor:  Accuracy: 18523/20000 (93%)

# %%
plots.plotDomainTraining(domain_train_history, train_history)

# %%
def mtx_dot(model_f, model_c, model_d, *args):
  return torch.mean(torch.pow(torch.mm(model_c.fc1.weight, torch.transpose(model_d.fc1.weight, 0, 1)), 2))

# %%
trainer_next = copy.deepcopy(model_trainer)

# %%
test_history2 = defaultdict(lambda:[])
train_history2 = defaultdict(lambda:[])
trainer_next.train(epochs, loaders, mtx_dot, train_history=train_history2, test_history=test_history2)
# Out:
# Train Epoch: 					1 [0/60000 (0%)]	Loss: 0.237084, p: 0.00000 lambd: 0.00000
# Train Epoch: 					1 [6400/60000 (11%)]	Loss: 0.206855, p: 0.01067 lambd: 0.05328
# Train Epoch: 					1 [12800/60000 (21%)]	Loss: 0.322853, p: 0.02133 lambd: 0.10626
# Train Epoch: 					1 [19200/60000 (32%)]	Loss: 0.248376, p: 0.03200 lambd: 0.15865
# Train Epoch: 					1 [25600/60000 (43%)]	Loss: 0.111864, p: 0.04267 lambd: 0.21015
# Train Epoch: 					1 [32000/60000 (53%)]	Loss: 0.541515, p: 0.05333 lambd: 0.26052
# Train Epoch: 					1 [38400/60000 (64%)]	Loss: 0.080789, p: 0.06400 lambd: 0.30951
# Train Epoch: 					1 [44800/60000 (75%)]	Loss: 0.042735, p: 0.07467 lambd: 0.35690
# Train Epoch: 					1 [51200/60000 (85%)]	Loss: 0.200494, p: 0.08533 lambd: 0.40253
# Train Epoch: 					1 [57600/60000 (96%)]	Loss: 0.163459, p: 0.09600 lambd: 0.44624
#
# Target Domain Test set: Average loss: 0.9210, Accuracy: 7218/10000 (72%)
#
# Source Domain Test set: Average loss: 0.0474, Accuracy: 9855/10000 (99%)
#
# Domains predictor:  Accuracy: 14428/20000 (72%)
#
# Train Epoch: 					2 [0/60000 (0%)]	Loss: 0.112387, p: 0.10000 lambd: 0.46212
# Train Epoch: 					2 [6400/60000 (11%)]	Loss: 0.130967, p: 0.11067 lambd: 0.50301
# Train Epoch: 					2 [12800/60000 (21%)]	Loss: 0.139829, p: 0.12133 lambd: 0.54178
# Train Epoch: 					2 [19200/60000 (32%)]	Loss: 0.132061, p: 0.13200 lambd: 0.57836
# Train Epoch: 					2 [25600/60000 (43%)]	Loss: 0.305719, p: 0.14267 lambd: 0.61276
# Train Epoch: 					2 [32000/60000 (53%)]	Loss: 0.511876, p: 0.15333 lambd: 0.64499
# Train Epoch: 					2 [38400/60000 (64%)]	Loss: 0.187775, p: 0.16400 lambd: 0.67507
# Train Epoch: 					2 [44800/60000 (75%)]	Loss: 0.133415, p: 0.17467 lambd: 0.70306
# Train Epoch: 					2 [51200/60000 (85%)]	Loss: 0.089938, p: 0.18533 lambd: 0.72904
# Train Epoch: 					2 [57600/60000 (96%)]	Loss: 0.227092, p: 0.19600 lambd: 0.75307
#
# Target Domain Test set: Average loss: 0.9101, Accuracy: 7297/10000 (73%)
#
# Source Domain Test set: Average loss: 0.0472, Accuracy: 9846/10000 (98%)
#
# Domains predictor:  Accuracy: 14644/20000 (73%)
#
# Train Epoch: 					3 [0/60000 (0%)]	Loss: 0.256926, p: 0.20000 lambd: 0.76159
# Train Epoch: 					3 [6400/60000 (11%)]	Loss: 0.092837, p: 0.21067 lambd: 0.78310
# Train Epoch: 					3 [12800/60000 (21%)]	Loss: 0.075841, p: 0.22133 lambd: 0.80288
# Train Epoch: 					3 [19200/60000 (32%)]	Loss: 0.219994, p: 0.23200 lambd: 0.82104
# Train Epoch: 					10 [44800/60000 (75%)]	Loss: 0.260188, p: 0.97467 lambd: 0.99988
# Train Epoch: 					10 [51200/60000 (85%)]	Loss: 0.217113, p: 0.98533 lambd: 0.99989
# Train Epoch: 					10 [57600/60000 (96%)]	Loss: 0.144876, p: 0.99600 lambd: 0.99991
#
# Target Domain Test set: Average loss: 0.9952, Accuracy: 7236/10000 (72%)
#
# Source Domain Test set: Average loss: 0.0491, Accuracy: 9854/10000 (99%)
#
# Domains predictor:  Accuracy: 14563/20000 (73%)

# %%
plots.plotTraining(train_history2)

# %%
trainer_next = copy.deepcopy(model_trainer)

# %%
def mtx_dot_len(model_c_len):
  def f(*args):
    model_f, model_c, model_d, *args = args
    return torch.mean(torch.pow(torch.mm(model_c.fc1.weight, torch.transpose(
        model_d.fc1.weight, 0, 1)), 2)) + torch.abs(model_c_len - torch.mean(
        torch.diag(torch.mm(model_c.fc1.weight, torch.transpose(
        model_c.fc1.weight, 0, 1)))))
  return f

# %%
test_history3 = defaultdict(lambda:[])
train_history3 = defaultdict(lambda:[])
f = mtx_dot_len(torch.mean(torch.diag(torch.mm(model_c.fc1.weight,
                                               torch.transpose(model_c.fc1.weight, 0, 1)))).item())
trainer_next.train(4, loaders, f, train_history=train_history3, test_history=test_history3)
# Out:
# Train Epoch: 					1 [0/60000 (0%)]	Loss: 0.320607, p: 0.00000 lambd: 0.00000
# Train Epoch: 					1 [6400/60000 (11%)]	Loss: 0.248122, p: 0.02667 lambd: 0.13255
# Train Epoch: 					1 [12800/60000 (21%)]	Loss: 0.138937, p: 0.05333 lambd: 0.26052
# Train Epoch: 					1 [19200/60000 (32%)]	Loss: 0.138584, p: 0.08000 lambd: 0.37995
# Train Epoch: 					1 [25600/60000 (43%)]	Loss: 0.147298, p: 0.10667 lambd: 0.48792
# Train Epoch: 					1 [32000/60000 (53%)]	Loss: 0.129678, p: 0.13333 lambd: 0.58278
# Train Epoch: 					1 [38400/60000 (64%)]	Loss: 0.107874, p: 0.16000 lambd: 0.66404
# Train Epoch: 					1 [44800/60000 (75%)]	Loss: 0.221816, p: 0.18667 lambd: 0.73214
# Train Epoch: 					1 [51200/60000 (85%)]	Loss: 0.372074, p: 0.21333 lambd: 0.78820
# Train Epoch: 					1 [57600/60000 (96%)]	Loss: 0.129717, p: 0.24000 lambd: 0.83365
#
# Target Domain Test set: Average loss: 0.8580, Accuracy: 7462/10000 (75%)
#
# Source Domain Test set: Average loss: 0.0521, Accuracy: 9840/10000 (98%)
#
# Domains predictor:  Accuracy: 13655/20000 (68%)
#
# Train Epoch: 					2 [0/60000 (0%)]	Loss: 0.176990, p: 0.25000 lambd: 0.84828
# Train Epoch: 					2 [6400/60000 (11%)]	Loss: 0.524931, p: 0.27667 lambd: 0.88170
# Train Epoch: 					2 [12800/60000 (21%)]	Loss: 0.301254, p: 0.30333 lambd: 0.90812
# Train Epoch: 					2 [19200/60000 (32%)]	Loss: 0.151405, p: 0.33000 lambd: 0.92886
# Train Epoch: 					2 [25600/60000 (43%)]	Loss: 0.125356, p: 0.35667 lambd: 0.94505
#
# Source Domain Test set: Average loss: 0.0482, Accuracy: 9852/10000 (99%)
#
# Domains predictor:  Accuracy: 14202/20000 (71%)

# %%
plots.plotTraining(train_history3)

# %%
trainer_next = copy.deepcopy(model_trainer)

# %%
test_history4 = defaultdict(lambda:[])
train_history4 = defaultdict(lambda:[])
f = mtx_dot_len(0)
trainer_next.train(4, loaders, f, train_history=train_history4, test_history=test_history4)
# Out:
# Train Epoch: 					1 [0/60000 (0%)]	Loss: 3.139045, p: 0.00000 lambd: 0.00000
# Train Epoch: 					1 [6400/60000 (11%)]	Loss: 0.699976, p: 0.02667 lambd: 0.13255
# Train Epoch: 					1 [12800/60000 (21%)]	Loss: 0.387614, p: 0.05333 lambd: 0.26052
# Train Epoch: 					1 [19200/60000 (32%)]	Loss: 0.370720, p: 0.08000 lambd: 0.37995
# Train Epoch: 					1 [25600/60000 (43%)]	Loss: 0.390108, p: 0.10667 lambd: 0.48792
# Train Epoch: 					1 [32000/60000 (53%)]	Loss: 0.312083, p: 0.13333 lambd: 0.58278
# Train Epoch: 					1 [38400/60000 (64%)]	Loss: 0.294295, p: 0.16000 lambd: 0.66404
# Train Epoch: 					1 [44800/60000 (75%)]	Loss: 0.434332, p: 0.18667 lambd: 0.73214
# Train Epoch: 					1 [51200/60000 (85%)]	Loss: 0.369008, p: 0.21333 lambd: 0.78820
# Train Epoch: 					1 [57600/60000 (96%)]	Loss: 0.641138, p: 0.24000 lambd: 0.83365
#
# Target Domain Test set: Average loss: 0.8088, Accuracy: 7604/10000 (76%)
#
# Source Domain Test set: Average loss: 0.0742, Accuracy: 9771/10000 (98%)
#
# Domains predictor:  Accuracy: 14563/20000 (73%)
#
# Train Epoch: 					2 [0/60000 (0%)]	Loss: 0.400039, p: 0.25000 lambd: 0.84828
# Train Epoch: 					2 [6400/60000 (11%)]	Loss: 0.464354, p: 0.27667 lambd: 0.88170
# Train Epoch: 					2 [12800/60000 (21%)]	Loss: 0.424667, p: 0.30333 lambd: 0.90812
# Train Epoch: 					2 [19200/60000 (32%)]	Loss: 0.367513, p: 0.33000 lambd: 0.92886
# Train Epoch: 					2 [25600/60000 (43%)]	Loss: 0.340075, p: 0.35667 lambd: 0.94505
# Train Epoch: 					2 [32000/60000 (53%)]	Loss: 0.537741, p: 0.38333 lambd: 0.95764
# Train Epoch: 					2 [38400/60000 (64%)]	Loss: 0.396598, p: 0.41000 lambd: 0.96740
# Train Epoch: 					2 [44800/60000 (75%)]	Loss: 0.455555, p: 0.43667 lambd: 0.97493
# Train Epoch: 					2 [51200/60000 (85%)]	Loss: 0.409509, p: 0.46333 lambd: 0.98074
# Train Epoch: 					2 [57600/60000 (96%)]	Loss: 0.497450, p: 0.49000 lambd: 0.98522
#
# Target Domain Test set: Average loss: 0.8539, Accuracy: 7621/10000 (76%)
#
# Source Domain Test set: Average loss: 0.0765, Accuracy: 9767/10000 (98%)
#
# Domains predictor:  Accuracy: 14117/20000 (71%)
#
# Train Epoch: 					3 [0/60000 (0%)]	Loss: 0.432309, p: 0.50000 lambd: 0.98661
# Train Epoch: 					3 [6400/60000 (11%)]	Loss: 0.408117, p: 0.52667 lambd: 0.98973
# Train Epoch: 					3 [12800/60000 (21%)]	Loss: 0.561199, p: 0.55333 lambd: 0.99213
# Train Epoch: 					3 [19200/60000 (32%)]	Loss: 0.304144, p: 0.58000 lambd: 0.99396
# Train Epoch: 					3 [25600/60000 (43%)]	Loss: 0.295168, p: 0.60667 lambd: 0.99537
# Train Epoch: 					3 [32000/60000 (53%)]	Loss: 0.578925, p: 0.63333 lambd: 0.99645
# Train Epoch: 					3 [38400/60000 (64%)]	Loss: 0.493631, p: 0.66000 lambd: 0.99728
# Train Epoch: 					3 [44800/60000 (75%)]	Loss: 0.520949, p: 0.68667 lambd: 0.99792
# Train Epoch: 					3 [51200/60000 (85%)]	Loss: 0.730475, p: 0.71333 lambd: 0.99841
# Train Epoch: 					3 [57600/60000 (96%)]	Loss: 0.437959, p: 0.74000 lambd: 0.99878
#
# Target Domain Test set: Average loss: 0.8511, Accuracy: 7407/10000 (74%)
#
# Source Domain Test set: Average loss: 0.0999, Accuracy: 9645/10000 (96%)
#
# Domains predictor:  Accuracy: 13989/20000 (70%)
#
# Train Epoch: 					4 [0/60000 (0%)]	Loss: 0.305464, p: 0.75000 lambd: 0.99889
# Train Epoch: 					4 [6400/60000 (11%)]	Loss: 0.298977, p: 0.77667 lambd: 0.99915
# Train Epoch: 					4 [12800/60000 (21%)]	Loss: 0.488333, p: 0.80333 lambd: 0.99935
# Train Epoch: 					4 [19200/60000 (32%)]	Loss: 0.436756, p: 0.83000 lambd: 0.99950
# Train Epoch: 					4 [25600/60000 (43%)]	Loss: 0.527018, p: 0.85667 lambd: 0.99962
# Train Epoch: 					4 [32000/60000 (53%)]	Loss: 0.563018, p: 0.88333 lambd: 0.99971
# Train Epoch: 					4 [38400/60000 (64%)]	Loss: 0.257315, p: 0.91000 lambd: 0.99978
# Train Epoch: 					4 [44800/60000 (75%)]	Loss: 0.466997, p: 0.93667 lambd: 0.99983
# Train Epoch: 					4 [51200/60000 (85%)]	Loss: 0.416275, p: 0.96333 lambd: 0.99987
# Train Epoch: 					4 [57600/60000 (96%)]	Loss: 0.443849, p: 0.99000 lambd: 0.99990
#
# Target Domain Test set: Average loss: 0.9644, Accuracy: 7315/10000 (73%)
#
# Source Domain Test set: Average loss: 0.0804, Accuracy: 9751/10000 (98%)
#
# Domains predictor:  Accuracy: 14214/20000 (71%)

# %%
plots.plotTraining(train_history4)

# %%
trainer_next = copy.deepcopy(model_trainer)

# %%
def mtx_dot_lens(model_c_len, model_d_len):
  def f(*args):
    model_f, model_c, model_d, *args = args
    return torch.mean(torch.pow(torch.mm(model_c.fc1.weight, torch.transpose(
        model_d.fc1.weight, 0, 1)), 2)) + torch.abs(model_c_len - torch.mean(
        torch.diag(torch.mm(model_c.fc1.weight, torch.transpose(
        model_c.fc1.weight, 0, 1))))) + torch.abs(model_d_len - torch.mean(
        torch.diag(torch.mm(model_d.fc1.weight, torch.transpose(
        model_d.fc1.weight, 0, 1)))))
  return f

# %%
test_history5 = defaultdict(lambda:[])
train_history5 = defaultdict(lambda:[])
f = mtx_dot_lens(0, 0)
trainer_next.train(4, loaders, f, train_history=train_history5, test_history=test_history5)
# Out:
# Train Epoch: 					1 [0/60000 (0%)]	Loss: 4.025530, p: 0.00000 lambd: 0.00000
# Train Epoch: 					1 [6400/60000 (11%)]	Loss: 1.225838, p: 0.02667 lambd: 0.13255
# Train Epoch: 					1 [12800/60000 (21%)]	Loss: 0.610220, p: 0.05333 lambd: 0.26052
# Train Epoch: 					1 [19200/60000 (32%)]	Loss: 0.451337, p: 0.08000 lambd: 0.37995
# Train Epoch: 					1 [25600/60000 (43%)]	Loss: 0.561328, p: 0.10667 lambd: 0.48792
# Train Epoch: 					1 [32000/60000 (53%)]	Loss: 0.561846, p: 0.13333 lambd: 0.58278
# Train Epoch: 					1 [38400/60000 (64%)]	Loss: 0.368538, p: 0.16000 lambd: 0.66404
# Train Epoch: 					1 [44800/60000 (75%)]	Loss: 0.466583, p: 0.18667 lambd: 0.73214
# Train Epoch: 					1 [51200/60000 (85%)]	Loss: 0.682216, p: 0.21333 lambd: 0.78820
# Train Epoch: 					1 [57600/60000 (96%)]	Loss: 0.332828, p: 0.24000 lambd: 0.83365
#
# Target Domain Test set: Average loss: 0.8901, Accuracy: 7483/10000 (75%)
#
# Source Domain Test set: Average loss: 0.0831, Accuracy: 9734/10000 (97%)
#
# Domains predictor:  Accuracy: 13588/20000 (68%)
#
# Train Epoch: 					2 [0/60000 (0%)]	Loss: 0.285808, p: 0.25000 lambd: 0.84828
# Train Epoch: 					2 [6400/60000 (11%)]	Loss: 0.455645, p: 0.27667 lambd: 0.88170
# Train Epoch: 					2 [12800/60000 (21%)]	Loss: 0.359122, p: 0.30333 lambd: 0.90812
# Train Epoch: 					2 [19200/60000 (32%)]	Loss: 0.446452, p: 0.33000 lambd: 0.92886
# Train Epoch: 					2 [25600/60000 (43%)]	Loss: 0.421921, p: 0.35667 lambd: 0.94505
# Train Epoch: 					2 [32000/60000 (53%)]	Loss: 0.338754, p: 0.38333 lambd: 0.95764
# Train Epoch: 					2 [38400/60000 (64%)]	Loss: 0.394183, p: 0.41000 lambd: 0.96740
# Train Epoch: 					2 [44800/60000 (75%)]	Loss: 0.544180, p: 0.43667 lambd: 0.97493
# Train Epoch: 					2 [51200/60000 (85%)]	Loss: 0.289207, p: 0.46333 lambd: 0.98074
# Train Epoch: 					2 [57600/60000 (96%)]	Loss: 0.255781, p: 0.49000 lambd: 0.98522
#
# Target Domain Test set: Average loss: 0.8387, Accuracy: 7598/10000 (76%)
#
# Source Domain Test set: Average loss: 0.0711, Accuracy: 9771/10000 (98%)
#
# Domains predictor:  Accuracy: 13985/20000 (70%)
#
# Train Epoch: 					3 [0/60000 (0%)]	Loss: 0.492819, p: 0.50000 lambd: 0.98661
# Train Epoch: 					3 [6400/60000 (11%)]	Loss: 0.368958, p: 0.52667 lambd: 0.98973
# Train Epoch: 					3 [12800/60000 (21%)]	Loss: 0.389254, p: 0.55333 lambd: 0.99213
# Train Epoch: 					3 [19200/60000 (32%)]	Loss: 0.471675, p: 0.58000 lambd: 0.99396
# Train Epoch: 					3 [25600/60000 (43%)]	Loss: 0.539868, p: 0.60667 lambd: 0.99537
# Train Epoch: 					3 [32000/60000 (53%)]	Loss: 0.442525, p: 0.63333 lambd: 0.99645
# Train Epoch: 					3 [38400/60000 (64%)]	Loss: 0.366660, p: 0.66000 lambd: 0.99728
# Train Epoch: 					3 [44800/60000 (75%)]	Loss: 0.486457, p: 0.68667 lambd: 0.99792
# Train Epoch: 					3 [51200/60000 (85%)]	Loss: 0.431645, p: 0.71333 lambd: 0.99841
# Train Epoch: 					3 [57600/60000 (96%)]	Loss: 0.448236, p: 0.74000 lambd: 0.99878
#
# Target Domain Test set: Average loss: 0.9227, Accuracy: 7503/10000 (75%)
#
# Source Domain Test set: Average loss: 0.0924, Accuracy: 9703/10000 (97%)
#
# Domains predictor:  Accuracy: 14168/20000 (71%)
#
# Train Epoch: 					4 [0/60000 (0%)]	Loss: 0.587406, p: 0.75000 lambd: 0.99889
# Train Epoch: 					4 [6400/60000 (11%)]	Loss: 0.381869, p: 0.77667 lambd: 0.99915
# Train Epoch: 					4 [12800/60000 (21%)]	Loss: 0.633856, p: 0.80333 lambd: 0.99935
# Train Epoch: 					4 [19200/60000 (32%)]	Loss: 0.369013, p: 0.83000 lambd: 0.99950
# Train Epoch: 					4 [25600/60000 (43%)]	Loss: 0.627045, p: 0.85667 lambd: 0.99962
# Train Epoch: 					4 [32000/60000 (53%)]	Loss: 0.345414, p: 0.88333 lambd: 0.99971
# Train Epoch: 					4 [38400/60000 (64%)]	Loss: 0.543468, p: 0.91000 lambd: 0.99978
# Train Epoch: 					4 [44800/60000 (75%)]	Loss: 0.563070, p: 0.93667 lambd: 0.99983
# Train Epoch: 					4 [51200/60000 (85%)]	Loss: 0.589240, p: 0.96333 lambd: 0.99987
# Train Epoch: 					4 [57600/60000 (96%)]	Loss: 0.448024, p: 0.99000 lambd: 0.99990
#
# Target Domain Test set: Average loss: 0.9080, Accuracy: 7227/10000 (72%)
#
# Source Domain Test set: Average loss: 0.0819, Accuracy: 9751/10000 (98%)
#
# Domains predictor:  Accuracy: 14203/20000 (71%)

# %%
plots.plotTraining(train_history5)

# %%
model_f_adam = models.MnistFeatureExtractor().to(device)
model_c_adam = models.MnistClassPredictor().to(device)
model_d_adam = models.MnistDomain().to(device)
lr=0.001
adam_f = optim.Adam(model_f_adam.parameters(), lr=lr)
adam_c = optim.Adam(model_c_adam.parameters(), lr=lr)
adam_d = optim.Adam(model_d_adam.parameters(), lr=lr)

adam_models = Models(model_f_adam, model_c_adam, model_d_adam)
adam_optims = Optims(adam_f, adam_c, adam_d)

# %%
adam_trainer = trainer.Trainer(adam_models, adam_optims, criterions, device)

# %%
adam_test_history = defaultdict(lambda:[])
adam_train_history = defaultdict(lambda:[])
adam_trainer.train(epochs, loaders, train_history=adam_train_history, test_history=adam_test_history)
# Out:
# Train Epoch: 					1 [0/60000 (0%)]	Loss: 2.331116, p: 0.00000 lambd: 0.00000
# Train Epoch: 					1 [6400/60000 (11%)]	Loss: 0.464603, p: 0.01067 lambd: 0.05328
# Train Epoch: 					3 [44800/60000 (75%)]	Loss: 0.045067, p: 0.27467 lambd: 0.87945
# Train Epoch: 					3 [51200/60000 (85%)]	Loss: 0.118464, p: 0.28533 lambd: 0.89098
# Train Epoch: 					3 [57600/60000 (96%)]	Loss: 0.230796, p: 0.29600 lambd: 0.90147
#
# Target Domain Test set: Average loss: 1.0320, Accuracy: 7321/10000 (73%)
#
# Source Domain Test set: Average loss: 0.0668, Accuracy: 9778/10000 (98%)
#
# Domains predictor:  Accuracy: 13878/20000 (69%)
#
# Train Epoch: 					4 [0/60000 (0%)]	Loss: 0.309925, p: 0.30000 lambd: 0.90515
# Train Epoch: 					4 [6400/60000 (11%)]	Loss: 0.382414, p: 0.31067 lambd: 0.91433
# Train Epoch: 					4 [12800/60000 (21%)]	Loss: 0.195164, p: 0.32133 lambd: 0.92267
# Train Epoch: 					4 [19200/60000 (32%)]	Loss: 0.354516, p: 0.33200 lambd: 0.93022
# Train Epoch: 					4 [25600/60000 (43%)]	Loss: 0.155681, p: 0.34267 lambd: 0.93706
# Train Epoch: 					4 [32000/60000 (53%)]	Loss: 0.090925, p: 0.35333 lambd: 0.94324
# Train Epoch: 					4 [38400/60000 (64%)]	Loss: 0.058874, p: 0.36400 lambd: 0.94884
# Train Epoch: 					4 [44800/60000 (75%)]	Loss: 0.105687, p: 0.37467 lambd: 0.95390
# Train Epoch: 					4 [51200/60000 (85%)]	Loss: 0.136320, p: 0.38533 lambd: 0.95846
# Train Epoch: 					4 [57600/60000 (96%)]	Loss: 0.128591, p: 0.39600 lambd: 0.96259
#
# Target Domain Test set: Average loss: 0.8100, Accuracy: 7662/10000 (77%)
#
# Source Domain Test set: Average loss: 0.0550, Accuracy: 9827/10000 (98%)
#
# Domains predictor:  Accuracy: 13832/20000 (69%)
#
# Train Epoch: 					5 [0/60000 (0%)]	Loss: 0.144008, p: 0.40000 lambd: 0.96403
# Train Epoch: 					5 [6400/60000 (11%)]	Loss: 0.122288, p: 0.41067 lambd: 0.96761
# Train Epoch: 					5 [12800/60000 (21%)]	Loss: 0.089775, p: 0.42133 lambd: 0.97084
# Train Epoch: 					5 [19200/60000 (32%)]	Loss: 0.255047, p: 0.43200 lambd: 0.97375
# Train Epoch: 					5 [25600/60000 (43%)]	Loss: 0.110822, p: 0.44267 lambd: 0.97637
# Train Epoch: 					5 [32000/60000 (53%)]	Loss: 0.146240, p: 0.45333 lambd: 0.97874
# Train Epoch: 					5 [38400/60000 (64%)]	Loss: 0.288573, p: 0.46400 lambd: 0.98087
# Train Epoch: 					5 [44800/60000 (75%)]	Loss: 0.210966, p: 0.47467 lambd: 0.98279
# Train Epoch: 					5 [51200/60000 (85%)]	Loss: 0.290349, p: 0.48533 lambd: 0.98452
# Train Epoch: 					5 [57600/60000 (96%)]	Loss: 0.181184, p: 0.49600 lambd: 0.98607
#
# Target Domain Test set: Average loss: 0.9091, Accuracy: 7562/10000 (76%)
#
# Source Domain Test set: Average loss: 0.0517, Accuracy: 9841/10000 (98%)
#
# Domains predictor:  Accuracy: 14201/20000 (71%)
# Target Domain Test set: Average loss: 0.8201, Accuracy: 7821/10000 (78%)
#
# Source Domain Test set: Average loss: 0.0541, Accuracy: 9838/10000 (98%)
#
# Domains predictor:  Accuracy: 13469/20000 (67%)

# %%
plots.plotTraining(adam_train_history)

# %%
plots.plotTest(adam_test_history)

# %% [markdown]
# ### Refactored end

# %%
new_gr_model = MnistDomain()
new_gr_model.load_state_dict(domain_pred.state_dict())
new_gr_model = new_gr_model.to(device)

# %%
dom_pr = nn.Sequential(model_f, new_gr_model)
testDomainPred(dom_pr, device, mnist_ext_test_loader)

# %%
model_cc = copy.deepcopy(model_c)
model_fc = copy.deepcopy(model_f)
optim_f = optim.SGD(model_fc.parameters(), lr=lr, momentum=momentum)
optim_c = optim.SGD(model_cc.parameters(), lr=lr, momentum=momentum)
optim_d = optim.SGD(new_gr_model.parameters(), lr=lr, momentum=momentum)

# %%
test_history5 = defaultdict(lambda:[])
train_history5 = defaultdict(lambda:[])
for epoch in range(1, epochs+1):
  trainWithDomain(model_fc, model_cc, new_gr_model, device,train_loader,
                 mnist_m_train_loader, optim_f, optim_c,
                 optim_d, epoch, epochs, train_domain=True,
                 train_history=train_history5)
  testDomainModel(model_fc, model_cc, new_gr_model, device,
                 test_loader, mnist_m_test_loader, mnist_ext_test_loader,
                 test_history=test_history5)

# %%
plots.plotTraining(train_history5)

# %%
dom_pr = nn.Sequential(model_fc, new_gr_model)
testDomainPred(dom_pr, device, mnist_ext_test_loader)

# %%
dom_pr = nn.Sequential(model_fc, domain_pred)
testDomainPred(dom_pr, device, mnist_ext_test_loader)

# %%
epochs=3
domain_train_history2 = defaultdict(lambda:[])
domain_pred2 = Domain().to(device)
lr = 0.01
optim_domain = optim.SGD(domain_pred2.parameters(), lr=lr, momentum=momentum)
for epoch in range(1, epochs+1):
  trainDomain(model_fc, domain_pred2, device, mnist_ext_train_loader, optim_domain,
              epoch, True, model_dc, model_cc, domain_train_history2)
  testDomainPred(nn.Sequential(model_fc, domain_pred2), device, mnist_ext_test_loader)

# %%
plots.plotDomainTraining(domain_train_history2, train_history5)

# %%
# Tests from different training methods

# %%
plots.plotTest(test_history2)

# %%
plots.plotTest(test_history3)

# %%
plots.plotTest(test_history4)

# %%
plots.plotTest(test_history5)

# %%
plots.plotTest(test_history6)

# %%
#After training with minimalizing lens of model_c and model_d matrices
model_cc_mtx = model_cc.fc1.weight.cpu().detach().numpy()
model_dc_mtx = model_dc.fc1.weight.cpu().detach().numpy()
model_cc_mtx.dot(model_dc_mtx.T)

# %%
np.mean(model_cc_mtx.dot(model_dc_mtx.T))

# %%
model_cc = copy.deepcopy(model_c)
model_fc = copy.deepcopy(model_f)
new_domain_pred = Domain().to(device)
optim_f = optim.SGD(model_fc.parameters(), lr=lr, momentum=momentum)
optim_c = optim.SGD(model_cc.parameters(), lr=lr, momentum=momentum)
optim_d = optim.SGD(new_domain_pred.parameters(), lr=lr, momentum=momentum)

# %%
test_history10 = defaultdict(lambda:[])
train_history10 = defaultdict(lambda:[])
for epoch in range(1, epochs+1):
  trainWithDomain(model_fc, model_cc, new_domain_pred, device,train_loader,
                 mnist_m_train_loader, optim_f, optim_c,
                 optim_d, epoch, epochs, train_domain=True,
                 train_history=train_history10,
                 extra_loss=mtx_dot)
  testDomainModel(model_fc, model_cc, new_domain_pred, device,
                 test_loader, mnist_m_test_loader, mnist_ext_test_loader,
                 test_history=test_history10)

# %%
plots.plotTraining(train_history10)

# %%
plots.plotTest(test_history10)

# %%
outputSize=210

# %%
new_model_f = models.extendFeatureExtractor(200).to(device)
model_cc = models.MnistClassPredictor(200).to(device)
model_dc = models.MnistDomain(200).to(device)
optim_f = optim.SGD(new_model_f.parameters(), lr=lr, momentum=momentum)
optim_c = optim.SGD(model_cc.parameters(), lr=lr, momentum=momentum)
optim_d = optim.SGD(model_dc.parameters(), lr=lr, momentum=momentum)

# %%
epochs=6

# %%
test_history11 = defaultdict(lambda:[])
train_history11 = defaultdict(lambda:[])
for epoch in range(1, epochs+1):
  trainWithDomain(new_model_f, model_cc, model_dc, device,train_loader,
                 mnist_m_train_loader, optim_f, optim_c,
                 optim_d, epoch, epochs, train_domain=True,
                 train_history=train_history11)
  testDomainModel(new_model_f, model_cc, model_dc, device,
                 test_loader, mnist_m_test_loader, mnist_ext_test_loader,
                 test_history=test_history11)
# Out:
# Train Epoch:               1 [0/60000 (0%)]	Loss: 2.327745, lr: 0.01000 lambd: 0.00000
# Train Epoch:               1 [6400/60000 (11%)]	Loss: 0.633662, lr: 0.00885 lambd: 0.08866
# Train Epoch:               1 [12800/60000 (21%)]	Loss: 0.420202, lr: 0.00796 lambd: 0.17593
# Train Epoch:               1 [19200/60000 (32%)]	Loss: 0.546820, lr: 0.00726 lambd: 0.26052
# Train Epoch:               1 [25600/60000 (43%)]	Loss: 0.566361, lr: 0.00668 lambd: 0.34129
# Train Epoch:               1 [32000/60000 (53%)]	Loss: 0.263927, lr: 0.00621 lambd: 0.41732
# Train Epoch:               1 [38400/60000 (64%)]	Loss: 0.371908, lr: 0.00580 lambd: 0.48792
# Train Epoch:               1 [44800/60000 (75%)]	Loss: 0.547279, lr: 0.00545 lambd: 0.55267
# Train Epoch:               1 [51200/60000 (85%)]	Loss: 0.561865, lr: 0.00515 lambd: 0.61137
# Train Epoch:               1 [57600/60000 (96%)]	Loss: 0.309172, lr: 0.00488 lambd: 0.66404
#
# Target Domain Test set: Average loss: 1.9422, Accuracy: 6148/10000 (61%)
#
# Source Domain Test set: Average loss: 0.1053, Accuracy: 9640/10000 (96%)
#
# Domains predictor:  Accuracy: 13252/20000 (66%)
#
# Train Epoch:               2 [0/60000 (0%)]	Loss: 0.500830, lr: 0.00479 lambd: 0.68226
# Train Epoch:               2 [6400/60000 (11%)]	Loss: 0.296036, lr: 0.00457 lambd: 0.72695
# Train Epoch:               2 [12800/60000 (21%)]	Loss: 0.254395, lr: 0.00436 lambd: 0.76622
# Train Epoch:               2 [19200/60000 (32%)]	Loss: 0.299445, lr: 0.00418 lambd: 0.80050
# Train Epoch:               2 [25600/60000 (43%)]	Loss: 0.307085, lr: 0.00401 lambd: 0.83023
# Train Epoch:               2 [32000/60000 (53%)]	Loss: 0.335940, lr: 0.00386 lambd: 0.85589
# Train Epoch:               2 [38400/60000 (64%)]	Loss: 0.410444, lr: 0.00372 lambd: 0.87793
# Train Epoch:               2 [44800/60000 (75%)]	Loss: 0.467758, lr: 0.00360 lambd: 0.89679
# Train Epoch:               2 [51200/60000 (85%)]	Loss: 0.166371, lr: 0.00348 lambd: 0.91286
# Train Epoch:               2 [57600/60000 (96%)]	Loss: 0.651762, lr: 0.00337 lambd: 0.92653
#
# Target Domain Test set: Average loss: 1.9308, Accuracy: 6718/10000 (67%)
#
# Source Domain Test set: Average loss: 0.0890, Accuracy: 9715/10000 (97%)
#
# Domains predictor:  Accuracy: 12739/20000 (64%)
#
# Train Epoch:               3 [0/60000 (0%)]	Loss: 0.479873, lr: 0.00333 lambd: 0.93111
# Train Epoch:               3 [6400/60000 (11%)]	Loss: 0.321929, lr: 0.00323 lambd: 0.94200
# Train Epoch:               3 [12800/60000 (21%)]	Loss: 0.351261, lr: 0.00314 lambd: 0.95122
# Train Epoch:               3 [19200/60000 (32%)]	Loss: 0.360810, lr: 0.00305 lambd: 0.95900
# Train Epoch:               3 [25600/60000 (43%)]	Loss: 0.182843, lr: 0.00297 lambd: 0.96556
# Train Epoch:               3 [32000/60000 (53%)]	Loss: 0.260039, lr: 0.00289 lambd: 0.97109
# Train Epoch:               3 [38400/60000 (64%)]	Loss: 0.156429, lr: 0.00282 lambd: 0.97574
# Train Epoch:               3 [44800/60000 (75%)]	Loss: 0.196656, lr: 0.00276 lambd: 0.97965
# Train Epoch:               3 [51200/60000 (85%)]	Loss: 0.270247, lr: 0.00269 lambd: 0.98294
# Train Epoch:               3 [57600/60000 (96%)]	Loss: 0.238339, lr: 0.00263 lambd: 0.98570
#
# Target Domain Test set: Average loss: 2.0098, Accuracy: 6848/10000 (68%)
#
# Source Domain Test set: Average loss: 0.0747, Accuracy: 9792/10000 (98%)
#
# Domains predictor:  Accuracy: 12492/20000 (62%)
#
# Train Epoch:               4 [0/60000 (0%)]	Loss: 0.274081, lr: 0.00261 lambd: 0.98661
# Train Epoch:               4 [6400/60000 (11%)]	Loss: 0.416917, lr: 0.00255 lambd: 0.98878
# Train Epoch:               4 [12800/60000 (21%)]	Loss: 0.200989, lr: 0.00250 lambd: 0.99060
# Train Epoch:               4 [19200/60000 (32%)]	Loss: 0.230864, lr: 0.00245 lambd: 0.99213
# Train Epoch:               4 [25600/60000 (43%)]	Loss: 0.372819, lr: 0.00240 lambd: 0.99340
# Train Epoch:               4 [32000/60000 (53%)]	Loss: 0.340552, lr: 0.00235 lambd: 0.99448
# Train Epoch:               4 [38400/60000 (64%)]	Loss: 0.270559, lr: 0.00231 lambd: 0.99537
# Train Epoch:               4 [44800/60000 (75%)]	Loss: 0.182093, lr: 0.00226 lambd: 0.99613
# Train Epoch:               4 [51200/60000 (85%)]	Loss: 0.685624, lr: 0.00222 lambd: 0.99676
# Train Epoch:               4 [57600/60000 (96%)]	Loss: 0.247288, lr: 0.00218 lambd: 0.99728
#
# Target Domain Test set: Average loss: 1.7976, Accuracy: 6847/10000 (68%)
#
# Source Domain Test set: Average loss: 0.0661, Accuracy: 9808/10000 (98%)
#
# Domains predictor:  Accuracy: 11742/20000 (59%)
#
# Train Epoch:               5 [0/60000 (0%)]	Loss: 0.116928, lr: 0.00217 lambd: 0.99746
# Train Epoch:               5 [6400/60000 (11%)]	Loss: 0.376819, lr: 0.00213 lambd: 0.99787
# Train Epoch:               5 [12800/60000 (21%)]	Loss: 0.213430, lr: 0.00210 lambd: 0.99822
# Train Epoch:               5 [19200/60000 (32%)]	Loss: 0.368740, lr: 0.00206 lambd: 0.99851
# Train Epoch:               5 [25600/60000 (43%)]	Loss: 0.345368, lr: 0.00203 lambd: 0.99875
# Train Epoch:               5 [32000/60000 (53%)]	Loss: 0.267094, lr: 0.00200 lambd: 0.99895
# Train Epoch:               5 [38400/60000 (64%)]	Loss: 0.397554, lr: 0.00197 lambd: 0.99912
# Train Epoch:               5 [44800/60000 (75%)]	Loss: 0.330269, lr: 0.00194 lambd: 0.99927
# Train Epoch:               5 [51200/60000 (85%)]	Loss: 0.251896, lr: 0.00191 lambd: 0.99939
# Train Epoch:               5 [57600/60000 (96%)]	Loss: 0.201644, lr: 0.00188 lambd: 0.99949
#
# Target Domain Test set: Average loss: 1.9657, Accuracy: 6900/10000 (69%)
#
# Source Domain Test set: Average loss: 0.0640, Accuracy: 9808/10000 (98%)
#
# Domains predictor:  Accuracy: 12212/20000 (61%)
#
# Train Epoch:               6 [0/60000 (0%)]	Loss: 0.127738, lr: 0.00187 lambd: 0.99952
# Train Epoch:               6 [6400/60000 (11%)]	Loss: 0.104216, lr: 0.00185 lambd: 0.99960
# Train Epoch:               6 [12800/60000 (21%)]	Loss: 0.339763, lr: 0.00182 lambd: 0.99966
# Train Epoch:               6 [19200/60000 (32%)]	Loss: 0.114392, lr: 0.00180 lambd: 0.99972
# Train Epoch:               6 [25600/60000 (43%)]	Loss: 0.134259, lr: 0.00177 lambd: 0.99976
# Train Epoch:               6 [32000/60000 (53%)]	Loss: 0.123254, lr: 0.00175 lambd: 0.99980
# Train Epoch:               6 [38400/60000 (64%)]	Loss: 0.397205, lr: 0.00173 lambd: 0.99983
# Train Epoch:               6 [44800/60000 (75%)]	Loss: 0.348418, lr: 0.00170 lambd: 0.99986
# Train Epoch:               6 [51200/60000 (85%)]	Loss: 0.147718, lr: 0.00168 lambd: 0.99988
# Train Epoch:               6 [57600/60000 (96%)]	Loss: 0.291815, lr: 0.00166 lambd: 0.99990
#
# Target Domain Test set: Average loss: 2.6822, Accuracy: 6728/10000 (67%)
#
# Source Domain Test set: Average loss: 0.0922, Accuracy: 9792/10000 (98%)
#
# Domains predictor:  Accuracy: 12644/20000 (63%)

# %%
plots.plotTraining(train_history11)

# %% [markdown]
# Testujemy rodzaje treningów:
#
#
# *   GR ze zmniejszaniem rozmiaru wyjścia pierwszej sieci
# *   Trening dwóch sieci bez GR ze zmniejszeniem rozmiaru wyjścia
# * Zmniejszenie rozmuaru wyjścia + modyfikacja lossa
#
# Zobaczymy, czy któraś z metod doprowadzi do wymuszenia odseparowania informacji.
